# %% [markdown]
# # Fold = 1 & Scaling 안했을 때 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling0_test_change, date_code_lst = load_data( fold = 1, scaling = 0 )
# Out:
# --- 27.810770988464355 seconds ---
# --- 20.841413736343384 seconds ---
# (49940, 550) (16119, 550)
# 권장 scale_pos_weight : 8.461917392951875
# 1번째 fold의 0번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling0_train_pred, fold_1_scaling0_train_prob, fold_1_scaling0_test_pred , fold_1_scaling0_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.620023	valid_0's binary_logloss: 0.676232
# [10]	valid_0's auc: 0.627784	valid_0's binary_logloss: 0.666091
# [15]	valid_0's auc: 0.628657	valid_0's binary_logloss: 0.658877
# [20]	valid_0's auc: 0.629732	valid_0's binary_logloss: 0.652949
# [25]	valid_0's auc: 0.631353	valid_0's binary_logloss: 0.649356
# [30]	valid_0's auc: 0.63333	valid_0's binary_logloss: 0.64526
# [35]	valid_0's auc: 0.633379	valid_0's binary_logloss: 0.642055
# [40]	valid_0's auc: 0.634139	valid_0's binary_logloss: 0.638424
# [45]	valid_0's auc: 0.634416	valid_0's binary_logloss: 0.635173
# [50]	valid_0's auc: 0.635263	valid_0's binary_logloss: 0.632569
# [55]	valid_0's auc: 0.636311	valid_0's binary_logloss: 0.63036
# [60]	valid_0's auc: 0.635517	valid_0's binary_logloss: 0.627904
# [65]	valid_0's auc: 0.635937	valid_0's binary_logloss: 0.625274
# [70]	valid_0's auc: 0.635244	valid_0's binary_logloss: 0.623584
# [75]	valid_0's auc: 0.635062	valid_0's binary_logloss: 0.621047
# [80]	valid_0's auc: 0.634495	valid_0's binary_logloss: 0.618941
# train_f1 score:  0.3129750271444083
# test_f1 score:  0.24744290318060808
#
# train_recall score:  0.6553618794998105
# test_recall score:  0.5101097631426921
#
# train_pre score:  0.20557470581243315
# test_pre score:  0.1633370329263781
#
# train acc score:  0.6959150981177413
# test acc score:  0.6667907438426701
#
#      y_true
# pred [883, 4523]
#      [848, 9865]
# ---1.3409323692321777 seconds ---

# %%
plot_distribute(fold_1_scaling0_test_prob, fold_1_scaling0_test_change)
# Out:
# 평균 값: 0.0007299140175198002
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 1 & Scaling 1 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling1_test_change, date_code_lst = load_data( fold = 1, scaling = 1 )
# Out:
# --- 29.05266785621643 seconds ---
# --- 21.82506823539734 seconds ---
# (49940, 550) (16119, 550)
# 권장 scale_pos_weight : 8.461917392951875
# 1번째 fold의 1번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling1_train_pred, fold_1_scaling1_train_prob, fold_1_scaling1_test_pred , fold_1_scaling1_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.619667	valid_0's binary_logloss: 0.679361
# [10]	valid_0's auc: 0.633683	valid_0's binary_logloss: 0.668022
# [15]	valid_0's auc: 0.634161	valid_0's binary_logloss: 0.660961
# [20]	valid_0's auc: 0.634599	valid_0's binary_logloss: 0.656277
# [25]	valid_0's auc: 0.633993	valid_0's binary_logloss: 0.650266
# [30]	valid_0's auc: 0.636068	valid_0's binary_logloss: 0.646724
# [35]	valid_0's auc: 0.636325	valid_0's binary_logloss: 0.64323
# [40]	valid_0's auc: 0.635718	valid_0's binary_logloss: 0.638858
# [45]	valid_0's auc: 0.63526	valid_0's binary_logloss: 0.636075
# [50]	valid_0's auc: 0.637017	valid_0's binary_logloss: 0.632375
# [55]	valid_0's auc: 0.636283	valid_0's binary_logloss: 0.629628
# [60]	valid_0's auc: 0.635626	valid_0's binary_logloss: 0.627409
# [65]	valid_0's auc: 0.634371	valid_0's binary_logloss: 0.624408
# [70]	valid_0's auc: 0.634692	valid_0's binary_logloss: 0.622068
# [75]	valid_0's auc: 0.634256	valid_0's binary_logloss: 0.620398
# train_f1 score:  0.3146116911149288
# test_f1 score:  0.2453429005105561
#
# train_recall score:  0.6765820386510042
# test_recall score:  0.5135759676487579
#
# train_pre score:  0.20495896229122423
# test_pre score:  0.16116751269035534
#
# train acc score:  0.6884461353624349
# test acc score:  0.6607109622184999
#
#      y_true
# pred [889, 4627]
#      [842, 9761]
# ---1.05611252784729 seconds ---

# %%
plot_distribute(fold_1_scaling1_test_prob, fold_1_scaling1_test_change)
# Out:
# 평균 값: 0.0007299140175198002
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 1 & Scaling 2 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling2_test_change, date_code_lst = load_data( fold = 1, scaling = 2 )
# Out:
# --- 32.016836643218994 seconds ---
# --- 22.812330722808838 seconds ---
# (49896, 550) (16117, 550)
# 권장 scale_pos_weight : 8.45537237066515
# 1번째 fold의 2번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling2_train_pred, fold_1_scaling2_train_prob, fold_1_scaling2_test_pred , fold_1_scaling2_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.641525	valid_0's binary_logloss: 0.671922
# [10]	valid_0's auc: 0.643691	valid_0's binary_logloss: 0.662508
# [15]	valid_0's auc: 0.645832	valid_0's binary_logloss: 0.65665
# [20]	valid_0's auc: 0.645159	valid_0's binary_logloss: 0.65241
# [25]	valid_0's auc: 0.646763	valid_0's binary_logloss: 0.647727
# [30]	valid_0's auc: 0.647414	valid_0's binary_logloss: 0.642616
# [35]	valid_0's auc: 0.648208	valid_0's binary_logloss: 0.639206
# [40]	valid_0's auc: 0.647908	valid_0's binary_logloss: 0.635871
# [45]	valid_0's auc: 0.647491	valid_0's binary_logloss: 0.633265
# [50]	valid_0's auc: 0.646807	valid_0's binary_logloss: 0.630613
# [55]	valid_0's auc: 0.64721	valid_0's binary_logloss: 0.628356
# [60]	valid_0's auc: 0.646843	valid_0's binary_logloss: 0.625506
# train_f1 score:  0.288487170943019
# test_f1 score:  0.24864446165762974
#
# train_recall score:  0.6562440780746637
# test_recall score:  0.5563258232235702
#
# train_pre score:  0.18488067908814265
# test_pre score:  0.1600997506234414
#
# train acc score:  0.6576479076479076
# test acc score:  0.6388906123968481
#
#      y_true
# pred [963, 5052]
#      [768, 9334]
# ---0.9919662475585938 seconds ---

# %%
plot_distribute(fold_1_scaling2_test_prob, fold_1_scaling2_test_change)
# Out:
# 평균 값: 0.0007309615920762795
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 1 & Scaling 3 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, fold_1_scaling3_test_change, test_change, date_code_lst = load_data( fold = 1, scaling = 3 )
# Out:
# --- 31.69203209877014 seconds ---
# --- 20.53732442855835 seconds ---
# (49461, 550) (31904, 550)
# 권장 scale_pos_weight : 8.326984725627003
# 1번째 fold의 3번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling3_train_pred, fold_1_scaling3_train_prob, fold_1_scaling3_test_pred , fold_1_scaling3_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.619901	valid_0's binary_logloss: 0.690621
# [10]	valid_0's auc: 0.618219	valid_0's binary_logloss: 0.694213
# [15]	valid_0's auc: 0.623516	valid_0's binary_logloss: 0.696998
# [20]	valid_0's auc: 0.625081	valid_0's binary_logloss: 0.697038
# [25]	valid_0's auc: 0.626408	valid_0's binary_logloss: 0.698197
# train_f1 score:  0.26587120867109937
# test_f1 score:  0.3085212532428657
#
# train_recall score:  0.5504431453894022
# test_recall score:  0.5745076179858789
#
# train_pre score:  0.1752626838787151
# test_pre score:  0.21088528168053472
#
# train acc score:  0.674086654131538
# test acc score:  0.5655717151454364
#
#      y_true
# pred [3092, 11570]
#      [2290, 14952]
# ---0.9158318042755127 seconds ---

# %%
plot_distribute(fold_1_scaling3_test_prob, fold_1_scaling3_test_change)
# Out:
# 평균 값: 0.0014776327646469688
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 1 & Scaling 4 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling4_test_change, date_code_lst = load_data( fold = 1, scaling = 4 )
# Out:
# --- 29.317353010177612 seconds ---
# --- 22.331236362457275 seconds ---
# (49940, 550) (16119, 550)
# 권장 scale_pos_weight : 8.461917392951875
# 1번째 fold의 4번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling4_train_pred, fold_1_scaling4_train_prob, fold_1_scaling4_test_pred , fold_1_scaling4_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.646917	valid_0's binary_logloss: 0.670619
# [10]	valid_0's auc: 0.645841	valid_0's binary_logloss: 0.658736
# [15]	valid_0's auc: 0.65097	valid_0's binary_logloss: 0.651187
# [20]	valid_0's auc: 0.650006	valid_0's binary_logloss: 0.64475
# [25]	valid_0's auc: 0.652218	valid_0's binary_logloss: 0.640176
# [30]	valid_0's auc: 0.65171	valid_0's binary_logloss: 0.635685
# [35]	valid_0's auc: 0.65285	valid_0's binary_logloss: 0.631567
# [40]	valid_0's auc: 0.653053	valid_0's binary_logloss: 0.62833
# [45]	valid_0's auc: 0.652627	valid_0's binary_logloss: 0.624802
# [50]	valid_0's auc: 0.65228	valid_0's binary_logloss: 0.622369
# [55]	valid_0's auc: 0.651708	valid_0's binary_logloss: 0.619757
# [60]	valid_0's auc: 0.651167	valid_0's binary_logloss: 0.617328
# train_f1 score:  0.3051876379690949
# test_f1 score:  0.2577363289529461
#
# train_recall score:  0.6286472148541115
# test_recall score:  0.5268630849220104
#
# train_pre score:  0.20150613385157293
# test_pre score:  0.17059483726150393
#
# train acc score:  0.6974769723668403
# test acc score:  0.6741112972268751
#
#      y_true
# pred [912, 4434]
#      [819, 9954]
# ---1.0599431991577148 seconds ---

# %%
plot_distribute(fold_1_scaling4_test_prob, fold_1_scaling4_test_change)
# Out:
# 평균 값: 0.0007299140175198002
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 2 & Scaling 안했을때 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling0_test_change, date_code_lst = load_data( fold = 2, scaling = 0 )
# Out:
# --- 41.33054232597351 seconds ---
# --- 25.50442409515381 seconds ---
# (81387, 550) (28430, 550)
# 권장 scale_pos_weight : 6.417023603390139
# 2번째 fold의 0번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling0_train_pred, fold_2_scaling0_train_prob, fold_2_scaling0_test_pred , fold_2_scaling0_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.601205	valid_0's binary_logloss: 0.666833
# [10]	valid_0's auc: 0.605479	valid_0's binary_logloss: 0.652159
# [15]	valid_0's auc: 0.60797	valid_0's binary_logloss: 0.64334
# [20]	valid_0's auc: 0.610749	valid_0's binary_logloss: 0.636188
# [25]	valid_0's auc: 0.613958	valid_0's binary_logloss: 0.630931
# [30]	valid_0's auc: 0.614418	valid_0's binary_logloss: 0.627347
# [35]	valid_0's auc: 0.614795	valid_0's binary_logloss: 0.623967
# [40]	valid_0's auc: 0.61549	valid_0's binary_logloss: 0.621766
# [45]	valid_0's auc: 0.6164	valid_0's binary_logloss: 0.619047
# [50]	valid_0's auc: 0.616735	valid_0's binary_logloss: 0.616415
# [55]	valid_0's auc: 0.617066	valid_0's binary_logloss: 0.614196
# [60]	valid_0's auc: 0.616995	valid_0's binary_logloss: 0.611681
# [65]	valid_0's auc: 0.616577	valid_0's binary_logloss: 0.609847
# [70]	valid_0's auc: 0.616286	valid_0's binary_logloss: 0.608219
# [75]	valid_0's auc: 0.618113	valid_0's binary_logloss: 0.606356
# [80]	valid_0's auc: 0.618196	valid_0's binary_logloss: 0.605186
# [85]	valid_0's auc: 0.617978	valid_0's binary_logloss: 0.602984
# [90]	valid_0's auc: 0.618257	valid_0's binary_logloss: 0.601216
# [95]	valid_0's auc: 0.618434	valid_0's binary_logloss: 0.600008
# [100]	valid_0's auc: 0.618622	valid_0's binary_logloss: 0.598698
# [105]	valid_0's auc: 0.618989	valid_0's binary_logloss: 0.596788
# [110]	valid_0's auc: 0.618761	valid_0's binary_logloss: 0.594959
# [115]	valid_0's auc: 0.618456	valid_0's binary_logloss: 0.593941
# [120]	valid_0's auc: 0.618414	valid_0's binary_logloss: 0.592755
# [125]	valid_0's auc: 0.617958	valid_0's binary_logloss: 0.591121
# [130]	valid_0's auc: 0.617964	valid_0's binary_logloss: 0.590023
# [135]	valid_0's auc: 0.617874	valid_0's binary_logloss: 0.589298
# train_f1 score:  0.39252834433557326
# test_f1 score:  0.2447335811648079
#
# train_recall score:  0.6042103344573043
# test_recall score:  0.36227453378171814
#
# train_pre score:  0.29068747807786743
# test_pre score:  0.1847809137689069
#
# train acc score:  0.74785899467974
# test acc score:  0.7427365459022159
#
#      y_true
# pred [1185, 5228]
#      [2086, 19931]
# ---1.9835176467895508 seconds ---

# %%
plot_distribute(fold_2_scaling0_test_prob, fold_2_scaling0_test_change)
# Out:
# 평균 값: 0.002314614723479945
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 2 & Scaling 1 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling1_test_change, date_code_lst = load_data( fold = 2, scaling = 1 )
# Out:
# --- 32.29491710662842 seconds ---
# --- 24.684823751449585 seconds ---
# (81387, 550) (28430, 550)
# 권장 scale_pos_weight : 6.417023603390139
# 2번째 fold의 1번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling1_train_pred, fold_2_scaling1_train_prob, fold_2_scaling1_test_pred , fold_2_scaling1_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.603432	valid_0's binary_logloss: 0.668711
# [10]	valid_0's auc: 0.608125	valid_0's binary_logloss: 0.657267
# [15]	valid_0's auc: 0.612407	valid_0's binary_logloss: 0.647769
# [20]	valid_0's auc: 0.613849	valid_0's binary_logloss: 0.642188
# [25]	valid_0's auc: 0.615146	valid_0's binary_logloss: 0.638608
# [30]	valid_0's auc: 0.617246	valid_0's binary_logloss: 0.636242
# [35]	valid_0's auc: 0.617239	valid_0's binary_logloss: 0.63383
# [40]	valid_0's auc: 0.617903	valid_0's binary_logloss: 0.632098
# [45]	valid_0's auc: 0.617452	valid_0's binary_logloss: 0.629632
# [50]	valid_0's auc: 0.616944	valid_0's binary_logloss: 0.62789
# [55]	valid_0's auc: 0.617086	valid_0's binary_logloss: 0.625426
# [60]	valid_0's auc: 0.617516	valid_0's binary_logloss: 0.623607
# [65]	valid_0's auc: 0.619051	valid_0's binary_logloss: 0.62037
# [70]	valid_0's auc: 0.619724	valid_0's binary_logloss: 0.617695
# [75]	valid_0's auc: 0.620094	valid_0's binary_logloss: 0.615756
# [80]	valid_0's auc: 0.619971	valid_0's binary_logloss: 0.614352
# [85]	valid_0's auc: 0.620659	valid_0's binary_logloss: 0.612258
# [90]	valid_0's auc: 0.620881	valid_0's binary_logloss: 0.611142
# [95]	valid_0's auc: 0.620701	valid_0's binary_logloss: 0.608618
# [100]	valid_0's auc: 0.619716	valid_0's binary_logloss: 0.606394
# [105]	valid_0's auc: 0.619943	valid_0's binary_logloss: 0.60485
# [110]	valid_0's auc: 0.619741	valid_0's binary_logloss: 0.603697
# train_f1 score:  0.3767423107936873
# test_f1 score:  0.24728890536657708
#
# train_recall score:  0.5960995169962635
# test_recall score:  0.40782635279730967
#
# train_pre score:  0.27539893057134435
# test_pre score:  0.17744080872572493
#
# train acc score:  0.7340852961775222
# test acc score:  0.7143510376362997
#
#      y_true
# pred [1334, 6184]
#      [1937, 18975]
# ---1.8294224739074707 seconds ---

# %%
plot_distribute(fold_2_scaling1_test_prob, fold_2_scaling1_test_change)
# Out:
# 평균 값: 0.002314614723479945
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 2 & Scaling 2 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling2_test_change, date_code_lst = load_data( fold = 2, scaling = 2 )
# Out:
# --- 37.4260311126709 seconds ---
# --- 25.352668046951294 seconds ---
# (81254, 550) (28397, 550)
# 권장 scale_pos_weight : 6.415039240737361
# 2번째 fold의 2번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling2_train_pred, fold_2_scaling2_train_prob, fold_2_scaling2_test_pred , fold_2_scaling2_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.629828	valid_0's binary_logloss: 0.657182
# [10]	valid_0's auc: 0.631168	valid_0's binary_logloss: 0.639459
# [15]	valid_0's auc: 0.633903	valid_0's binary_logloss: 0.628534
# [20]	valid_0's auc: 0.634742	valid_0's binary_logloss: 0.621815
# [25]	valid_0's auc: 0.634962	valid_0's binary_logloss: 0.617968
# [30]	valid_0's auc: 0.635409	valid_0's binary_logloss: 0.61425
# [35]	valid_0's auc: 0.635579	valid_0's binary_logloss: 0.611267
# [40]	valid_0's auc: 0.636058	valid_0's binary_logloss: 0.608049
# [45]	valid_0's auc: 0.636227	valid_0's binary_logloss: 0.606426
# [50]	valid_0's auc: 0.636576	valid_0's binary_logloss: 0.604524
# [55]	valid_0's auc: 0.636618	valid_0's binary_logloss: 0.603013
# [60]	valid_0's auc: 0.63701	valid_0's binary_logloss: 0.601754
# [65]	valid_0's auc: 0.637753	valid_0's binary_logloss: 0.599675
# [70]	valid_0's auc: 0.638317	valid_0's binary_logloss: 0.597882
# [75]	valid_0's auc: 0.637399	valid_0's binary_logloss: 0.596362
# [80]	valid_0's auc: 0.637052	valid_0's binary_logloss: 0.594442
# [85]	valid_0's auc: 0.637396	valid_0's binary_logloss: 0.593134
# [90]	valid_0's auc: 0.636546	valid_0's binary_logloss: 0.591629
# train_f1 score:  0.3627838104639684
# test_f1 score:  0.2581245926063879
#
# train_recall score:  0.603668552655594
# test_recall score:  0.4241126070991432
#
# train_pre score:  0.25931007448059584
# test_pre score:  0.18551733369026904
#
# train acc score:  0.7140079257636547
# test acc score:  0.719442194598021
#
#      y_true
# pred [1386, 6085]
#      [1882, 19044]
# ---1.7365567684173584 seconds ---

# %%
plot_distribute(fold_2_scaling2_test_prob, fold_2_scaling2_test_change)
# Out:
# 평균 값: 0.00233053122955123
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 2 & Scaling 3 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling3_test_change, date_code_lst = load_data( fold = 2, scaling = 3 )
# Out:
# --- 34.44538068771362 seconds ---
# --- 27.396940231323242 seconds ---
# (81387, 550) (28430, 550)
# 권장 scale_pos_weight : 6.417023603390139
# 2번째 fold의 3번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling3_train_pred, fold_2_scaling3_train_prob, fold_2_scaling3_test_pred , fold_2_scaling3_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.630922	valid_0's binary_logloss: 0.656058
# [10]	valid_0's auc: 0.637351	valid_0's binary_logloss: 0.634684
# [15]	valid_0's auc: 0.637296	valid_0's binary_logloss: 0.623402
# [20]	valid_0's auc: 0.637373	valid_0's binary_logloss: 0.616065
# [25]	valid_0's auc: 0.637356	valid_0's binary_logloss: 0.611362
# [30]	valid_0's auc: 0.63707	valid_0's binary_logloss: 0.607313
# [35]	valid_0's auc: 0.637412	valid_0's binary_logloss: 0.6046
# [40]	valid_0's auc: 0.638926	valid_0's binary_logloss: 0.600878
# [45]	valid_0's auc: 0.639496	valid_0's binary_logloss: 0.59935
# [50]	valid_0's auc: 0.638973	valid_0's binary_logloss: 0.596954
# [55]	valid_0's auc: 0.639013	valid_0's binary_logloss: 0.594445
# [60]	valid_0's auc: 0.639132	valid_0's binary_logloss: 0.592979
# [65]	valid_0's auc: 0.639653	valid_0's binary_logloss: 0.590431
# [70]	valid_0's auc: 0.639823	valid_0's binary_logloss: 0.588532
# [75]	valid_0's auc: 0.63843	valid_0's binary_logloss: 0.587487
# [80]	valid_0's auc: 0.639039	valid_0's binary_logloss: 0.585966
# [85]	valid_0's auc: 0.638886	valid_0's binary_logloss: 0.584462
# [90]	valid_0's auc: 0.638088	valid_0's binary_logloss: 0.582704
# [95]	valid_0's auc: 0.637393	valid_0's binary_logloss: 0.581462
# train_f1 score:  0.372595880277683
# test_f1 score:  0.25577475959155344
#
# train_recall score:  0.5967374464594914
# test_recall score:  0.39437480892693366
#
# train_pre score:  0.27085832471561533
# test_pre score:  0.1892605633802817
#
# train acc score:  0.7290476366004399
# test acc score:  0.7359479423144566
#
#      y_true
# pred [1290, 5526]
#      [1981, 19633]
# ---1.7665703296661377 seconds ---

# %%
plot_distribute(fold_2_scaling3_test_prob, fold_2_scaling3_test_change)
# Out:
# 평균 값: 0.002314614723479945
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fold = 2 & Scaling 4 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling4_test_change, date_code_lst = load_data( fold = 2, scaling = 4 )
# Out:
# --- 33.753042697906494 seconds ---
# --- 24.36216163635254 seconds ---
# (81387, 550) (28430, 550)
# 권장 scale_pos_weight : 6.417023603390139
# 2번째 fold의 4번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling4_train_pred, fold_2_scaling4_train_prob, fold_2_scaling4_test_pred , fold_2_scaling4_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.619837	valid_0's binary_logloss: 0.65821
# [10]	valid_0's auc: 0.624369	valid_0's binary_logloss: 0.636713
# [15]	valid_0's auc: 0.629413	valid_0's binary_logloss: 0.624231
# [20]	valid_0's auc: 0.630744	valid_0's binary_logloss: 0.616273
# [25]	valid_0's auc: 0.634104	valid_0's binary_logloss: 0.610303
# [30]	valid_0's auc: 0.636394	valid_0's binary_logloss: 0.604186
# [35]	valid_0's auc: 0.638351	valid_0's binary_logloss: 0.601049
# [40]	valid_0's auc: 0.638008	valid_0's binary_logloss: 0.598461
# [45]	valid_0's auc: 0.639882	valid_0's binary_logloss: 0.595018
# [50]	valid_0's auc: 0.641401	valid_0's binary_logloss: 0.592129
# [55]	valid_0's auc: 0.641062	valid_0's binary_logloss: 0.589988
# [60]	valid_0's auc: 0.640159	valid_0's binary_logloss: 0.588152
# [65]	valid_0's auc: 0.639793	valid_0's binary_logloss: 0.586145
# [70]	valid_0's auc: 0.64033	valid_0's binary_logloss: 0.583583
# [75]	valid_0's auc: 0.641389	valid_0's binary_logloss: 0.582169
# [80]	valid_0's auc: 0.640442	valid_0's binary_logloss: 0.580472
# [85]	valid_0's auc: 0.640083	valid_0's binary_logloss: 0.578967
# [90]	valid_0's auc: 0.63965	valid_0's binary_logloss: 0.577344
# [95]	valid_0's auc: 0.639314	valid_0's binary_logloss: 0.575871
# [100]	valid_0's auc: 0.63978	valid_0's binary_logloss: 0.573917
# train_f1 score:  0.39702096358955496
# test_f1 score:  0.25471184224861093
#
# train_recall score:  0.5902670190467512
# test_recall score:  0.3573830632833996
#
# train_pre score:  0.29909951512352806
# test_pre score:  0.19786729857819904
#
# train acc score:  0.7582660621475175
# test acc score:  0.7593739008090046
#
#      y_true
# pred [1169, 4739]
#      [2102, 20420]
# ---1.7783734798431396 seconds ---

# %%
plot_distribute(fold_2_scaling4_test_prob, fold_2_scaling4_test_change)
# Out:
# 평균 값: 0.002314614723479945
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # testset 라벨 별 히스토그램

# %%
label_0_lst=[]
label_1_lst=[]

for value in fold_2_scaling4_test_change:
    if value >= 0.05:
        label_1_lst.append(value)
    
    else:
        label_0_lst.append(value)

# %%
'''plt.xticks 에러 먹음 -30~30으로 바꿔줘야 함'''
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

ax=plt.figure(figsize=(12,6))
ax=sns.histplot(label_0_lst, bins = 35, label = 'label 0')
ax=sns.histplot(label_1_lst, bins=25, color = 'firebrick', label = 'label 1')
# plt.xticks(fontsize=15)

ax.set_xlabel('Change', fontsize=15)
ax.legend(fontsize=15)
# ax = plt.axvline(np.mean(fold_2_scaling4_test_change), linewidth=2, color = 'red')
# xtick_lst = np.array([-0.3, -0.2, -0.05, np.mean(fold_2_scaling4_test_change), 0.05, 0.2, 0.3])

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

fold_1prob_data =[fold_1_scaling0_test_prob, fold_1_scaling1_test_prob, fold_1_scaling2_test_prob,fold_1_scaling3_test_prob,fold_1_scaling4_test_prob]
fold_1change_data =[fold_1_scaling0_test_change, fold_1_scaling1_test_change, fold_1_scaling2_test_change, fold_1_scaling3_test_change, fold_1_scaling4_test_change]

data_lst = []

for i in range(5):
    if i== 0:
        scaling = 'none_scaling'
    elif i== 1:
        scaling = 'scaling1'
    elif i== 2:
        scaling = 'scaling2'
    elif i== 3:
        scaling = 'scaling3'
    elif i== 4:
        scaling = 'scaling4'
        
    for prob, change in zip(fold_1prob_data[i],fold_1change_data[i]):
        if prob >= 0.8:
            data_lst.append([scaling, prob, change, 1])
        elif 0.6 <= prob < 0.8:
            data_lst.append([scaling, prob, change, 2])
        elif 0.4 <= prob < 0.6:
            data_lst.append([scaling, prob, change, 3])
        elif 0.2 <= prob < 0.4:
            data_lst.append([scaling, prob, change, 4])
        elif prob < 0.2:
            data_lst.append([scaling, prob, change, 5])
data_df = pd.DataFrame(data_lst, columns = ['scaling', 'prob', 'change', 'predict_probability'])

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
scaling_lst = ['Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']
f,ax=plt.subplots(1,1,figsize=(20,12),sharex=False)
ax = sns.boxplot(data = data_df, 
                 x='scaling',
                 y='change', 
                 hue = 'predict_probability', 
                 palette = 'OrRd', 
                 hue_order = [5,4,3,2,1], 
                 )

ax.set_xticklabels(scaling_lst, fontsize=25)
ax.tick_params(axis='y', labelsize=25)
ax.set_xlabel('')
ax.set_ylabel('D-0 종가 변화율 [-30 ~ +30%]', fontsize=25)
ax.legend(title='predict_probability',fontsize=20)
legend_lst = ['0~20%', '20~40%', '40~60%','60~80%', '80~100%']

plt.axhline(0, color='y', linewidth = 5)

for i,text in enumerate(legend_lst):
    ax.legend_.texts[i].set_text(text)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

prob_data =[fold_2_scaling0_test_prob, fold_2_scaling1_test_prob, fold_2_scaling2_test_prob,fold_2_scaling3_test_prob,fold_2_scaling4_test_prob]
change_data =[fold_2_scaling0_test_change, fold_2_scaling1_test_change, fold_2_scaling2_test_change, fold_2_scaling3_test_change, fold_2_scaling4_test_change]

data_lst = []

for i in range(5):
    if i== 0:
        scaling = 'none_scaling'
    elif i== 1:
        scaling = 'scaling1'
    elif i== 2:
        scaling = 'scaling2'
    elif i== 3:
        scaling = 'scaling3'
    elif i== 4:
        scaling = 'scaling4'
    for prob, change in zip(prob_data[i],change_data[i]):
        if prob >= 0.8:
            data_lst.append([scaling, prob, change, 1])
        elif 0.6 <= prob < 0.8:
            data_lst.append([scaling, prob, change, 2])
        elif 0.4 <= prob < 0.6:
            data_lst.append([scaling, prob, change, 3])
        elif 0.2 <= prob < 0.4:
            data_lst.append([scaling, prob, change, 4])
        elif prob < 0.2:
            data_lst.append([scaling, prob, change, 5])
data_df = pd.DataFrame(data_lst, columns = ['scaling', 'prob', 'change', 'predict_probability'])

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
scaling_lst = ['Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']
f,ax=plt.subplots(1,1,figsize=(20,12),sharex=False)
ax = sns.boxplot(data = data_df, 
                 x='scaling',
                 y='change', 
                 hue = 'predict_probability', 
                 palette = 'OrRd', 
                 hue_order = [5,4,3,2,1], 
                 )
ax.set_xticklabels(scaling_lst, fontsize=25)
ax.tick_params(axis='y', labelsize=25)
ax.set_xlabel('')
ax.set_ylabel('change [-30 ~ +30%]', fontsize=25)
ax.legend(title='predict_probability',fontsize=20)
legend_lst = ['0~20%', '20~40%', '40~60%','60~80%', '80~100%']

plt.axhline(0, color='y', linewidth = 5)

plt.axhline(0, color='y', linewidth = 5)

for i,text in enumerate(legend_lst):
    ax.legend_.texts[i].set_text(text)

# %%
import pandas as pd
f2_s4_80_label_0=[]
f2_s4_80_label_1=[]
data = []
for prob,change in zip(fold_2_scaling4_test_prob, fold_2_scaling4_test_change):
    if prob >= 0.8 and change >= 0.05:
        f2_s4_80_label_1.append(change)
        data.append(change)
        
    elif prob >= 0.8 and change < 0.05:
        f2_s4_80_label_0.append(change)
        data.append(change)
data = (pd.Series(data) >= 0.05).value_counts()

# %%
data
# Out:
# False    31
# True     22
# dtype: int64

# %%
f, ax = plt.subplots(1,1,figsize=(12,6),sharex=False)


title = 'predited_imbalance_pie_chart'
labels = ['label 0', 'label 1']
ax.pie( data, colors = ['steelblue','firebrick'],
                                         startangle=90,
                                         autopct = '%1.2f%%', 
                                         labels=labels)
plt.legend(fontsize=15)

# %%
len(f2_s4_80_label_0)
# Out:
# 31

# %%
len(f2_s4_80_label_1)
# Out:
# 22

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
ax=plt.figure(figsize=(12,6))
ax = sns.histplot(f2_s4_80_label_0,bins = 14, label = 'label 0')
ax = sns.histplot(f2_s4_80_label_1,bins = 20, color='firebrick', label = 'label 1')
plt.legend(fontsize=20)

# %%
sns.histplot(f2_s4_80_label_1, bins = 25, color='r')
sns.histplot(f2_s4_80_label_0, bins = 35)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # 시뮬레이션 인덱스 플롯

# %%
from simulator import simulator
fold=1
for i,test_prob in enumerate(fold_1prob_data):
    if i ==0:
        scaling0_simul = simulator( date_code_lst, test_prob, fold )
    elif i ==1:
        scaling1_simul = simulator( date_code_lst, test_prob, fold )
    elif i==2:
        scaling2_simul = simulator( date_code_lst, test_prob, fold )
    elif i==3:
        scaling3_simul = simulator( date_code_lst, test_prob, fold )
    elif i==4:
        scaling4_simul = simulator( date_code_lst, test_prob, fold )
# Out:
# 시작 금액 : 100.0 만원
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1083702/1088862378.py in <module>
#       3 for i,test_prob in enumerate(fold_1prob_data):
#       4     if i ==0:
# ----> 5         scaling0_simul = simulator( date_code_lst, test_prob, fold )
#       6     elif i ==1:
#       7         scaling1_simul = simulator( date_code_lst, test_prob, fold )
#
# /project/dsml2022/inhovation97/code_for_paper/simulator.py in simulator(date_code_lst, test_prob, fold)
#      61
#      62
# ---> 63                 sell_stock_date = stock_lst[ii+1][0]
#      64                 sell_close_price = stock_lst[ii+1][4]
#      65                 sell_change = stock_lst[ii+1][6]
#
# IndexError: list index out of range

# %%
from functools import reduce

scaling0_simul_df = pd.DataFrame(scaling0_simul, columns=['sell_date', 'money'])
scaling1_simul_df = pd.DataFrame(scaling1_simul, columns=['sell_date', 'money'])
scaling2_simul_df = pd.DataFrame(scaling2_simul, columns=['sell_date', 'money'])
scaling3_simul_df = pd.DataFrame(scaling3_simul, columns=['sell_date', 'money'])
scaling4_simul_df = pd.DataFrame(scaling4_simul, columns=['sell_date', 'money'])

dfs = [scaling0_simul_df, scaling1_simul_df, scaling2_simul_df, scaling3_simul_df, scaling4_simul_df]

# 4개의 df를 한번에 merge하기
df_merge = reduce(lambda left, right: pd.merge(left, right, on='sell_date', how='outer',sort=True), dfs)


df_merge.columns=['sell_date', 'none_scaling', 'scaling1', 'scaling2', 'scaling3', 'scaling4']
df_merge

first_data = {
    'sell_date' : '2021-01-04', 
    'scaling1' : 1000000, 
    'scaling2' : 1000000, 
    'scaling3' : 1000000, 
    'scaling4' : 1000000
}

df_merge = df_merge.append(first_data, ignore_index=True)

df_merge = df_merge.sort_values(by=['sell_date'], axis=0).reset_index()
del df_merge['index']
df_merge = df_merge.fillna(method='ffill')

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(15,8))
sns.lineplot(data = df_merge, x="sell_date", y = "none_scaling", label='none_scaling', linewidth=4)
sns.lineplot(data = df_merge, x="sell_date", y = "scaling1", label='scaling1', linewidth=4)
sns.lineplot(data = df_merge, x="sell_date", y = "scaling2", label='scaling2', linewidth=4)
sns.lineplot(data = df_merge, x="sell_date", y = "scaling3", label='scaling3', linewidth=4)
sns.lineplot(data = df_merge, x="sell_date", y = "scaling4", label='scaling4', linewidth=4)
_=plt.xticks(range(0,81, 8), fontsize=15, rotation = 45)
_=plt.yticks()
_=plt.legend(fontsize=20)

# %% [markdown]
# ## fold2 수익률

# %%
from simulator import simulator
fold=2
for i,test_prob in enumerate(prob_data):
    if i ==0:
        scaling0_simul = simulator( date_code_lst, test_prob, fold )
    elif i ==1:
        scaling1_simul = simulator( date_code_lst, test_prob, fold )
    elif i==2:
        scaling2_simul = simulator( date_code_lst, test_prob, fold )
    elif i==3:
        scaling3_simul = simulator( date_code_lst, test_prob, fold )
    elif i==4:
        scaling4_simul = simulator( date_code_lst, test_prob, fold )
# Out:
# 시작 금액 : 100.0 만원
#
# 2021-02-15 : BUY 051980 -> 293주 구입, 매수 금액: 49.9565만원
# 2021-02-15 : BUY 004140 -> 51주 구입, 매수 금액: 49.0518만원
# 2021-02-16 : SELL 051980 -> 매도 금액 : 52.447만원, 전날 대비 상승률 0.04985337243401755:, 이익금 : 2.4905만원, 현재 자산 : 53.44만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 63.7143만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 14.6625만원, 현재 자산 : 117.15만원
#
# 2021-02-22 : BUY 127120 -> 218주 구입, 매수 금액: 117.066만원
# 2021-02-23 : SELL 127120 -> 매도 금액 : 112.27만원, 전날 대비 상승률 -0.040968342644320255:, 이익금 : -4.796만원, 현재 자산 : 112.36만원
#
# 2021-03-08 : BUY 009620 -> 920주 구입, 매수 금액: 112.24만원
# 2021-03-09 : SELL 009620 -> 매도 금액 : 116.38만원, 전날 대비 상승률 0.03688524590163933:, 이익금 : 4.14만원, 현재 자산 : 116.50만원
#
# 2021-03-11 : BUY 049080 -> 712주 구입, 매수 금액: 116.412만원
# 2021-03-12 : SELL 049080 -> 매도 금액 : 121.04만원, 전날 대비 상승률 0.039755351681957096:, 이익금 : 4.628만원, 현재 자산 : 121.12만원
#
# 2021-03-15 : BUY 053030 -> 75주 구입, 매수 금액: 121.125만원
# 2021-03-16 : SELL 053030 -> 매도 금액 : 148.5만원, 전날 대비 상승률 0.22600619195046434:, 이익금 : 27.375만원, 현재 자산 : 148.50만원
#
# 2021-03-22 : BUY 115450 -> 117주 구입, 매수 금액: 147.42만원
# 2021-03-23 : SELL 115450 -> 매도 금액 : 140.4만원, 전날 대비 상승률 -0.04761904761904767:, 이익금 : -7.02만원, 현재 자산 : 141.48만원
#
# 2021-03-25 : BUY 064090 -> 389주 구입, 매수 금액: 141.1292만원
# 2021-06-03 : SELL 101390 -> 매도 금액 : 200.804만원, 전날 대비 상승률 0.0973615756224453:, 이익금 : 17.816만원, 현재 자산 : 201.67만원
#
# 2021-06-03 : BUY 101390 -> 136주 구입, 매수 금액: 200.804만원
# 2021-06-04 : SELL 101390 -> 매도 금액 : 201.484만원, 전날 대비 상승률 0.0033863867253640656:, 이익금 : 0.68만원, 현재 자산 : 202.35만원
#
# 2021-06-29 : BUY 121850 -> 666주 구입, 매수 금액: 202.2642만원
# 2021-06-30 : SELL 121850 -> 매도 금액 : 207.0594만원, 전날 대비 상승률 0.02370760619031942:, 이익금 : 4.7952만원, 현재 자산 : 207.15만원
#
# 2021-07-02 : BUY 121850 -> 722주 구입, 매수 금액: 207.1418만원
# 2021-07-05 : SELL 121850 -> 매도 금액 : 208.2248만원, 전날 대비 상승률 0.005228302544440622:, 이익금 : 1.083만원, 현재 자산 : 208.23만원
#
# 2021-07-06 : BUY 121850 -> 684주 구입, 매수 금액: 208.0728만원
# 2021-07-07 : SELL 121850 -> 매도 금액 : 196.2396만원, 전날 대비 상승률 -0.05687047994740302:, 이익금 : -11.8332만원, 현재 자산 : 196.40만원
#
# 2021-08-18 : BUY 950130 -> 109주 구입, 매수 금액: 196.2만원
# 2021-08-19 : SELL 950130 -> 매도 금액 : 185.3만원, 전날 대비 상승률 -0.05555555555555558:, 이익금 : -10.9만원, 현재 자산 : 185.50만원
#
# 2021-08-20 : BUY 065440 -> 594주 구입, 매수 금액: 185.328만원
# 2021-08-23 : SELL 065440 -> 매도 금액 : 183.546만원, 전날 대비 상승률 -0.009615384615384581:, 이익금 : -1.782만원, 현재 자산 : 183.72만원
#
# 2021-09-14 : BUY 042040 -> 1208주 구입, 매수 금액: 183.616만원
# 2021-09-15 : SELL 042040 -> 매도 금액 : 181.804만원, 전날 대비 상승률 -0.009868421052631526:, 이익금 : -1.812만원, 현재 자산 : 181.91만원
#
# 2021-09-24 : BUY 042040 -> 1140주 구입, 매수 금액: 181.83만원
# 2021-09-27 : SELL 042040 -> 매도 금액 : 171.0만원, 전날 대비 상승률 -0.059561128526645746:, 이익금 : -10.83만원, 현재 자산 : 171.08만원
#
# 2021-09-30 : BUY 030790 -> 411주 구입, 매수 금액: 170.7705만원
# 2021-10-01 : SELL 030790 -> 매도 금액 : 169.743만원, 전날 대비 상승률 -0.006016847172081841:, 이익금 : -1.0275만원, 현재 자산 : 170.05만원
#
# 2021-10-07 : BUY 002290 -> 100주 구입, 매수 금액: 56.6만원
# 2021-10-07 : BUY 020180 -> 370주 구입, 매수 금액: 56.61만원
# 2021-10-07 : BUY 078650 -> 42주 구입, 매수 금액: 55.5702만원
# 2021-10-08 : SELL 002290 -> 매도 금액 : 57.5만원, 전날 대비 상승률 0.01590106007067127:, 이익금 : 0.9만원, 현재 자산 : 58.77만원
# 2021-10-08 : SELL 020180 -> 매도 금액 : 57.905만원, 전날 대비 상승률 0.02287581699346397:, 이익금 : 1.295만원, 현재 자산 : 116.67만원
# 2021-10-08 : SELL 078650 -> 매도 금액 : 53.9616만원, 전날 대비 상승률 -0.02894716952611287:, 이익금 : -1.6086만원, 현재 자산 : 170.63만원
#
# 2021-10-08 : BUY 208710 -> 557주 구입, 매수 금액: 170.442만원
# 2021-10-12 : SELL 208710 -> 매도 금액 : 171.8345만원, 전날 대비 상승률 0.008169934640522847:, 이익금 : 1.3925만원, 현재 자산 : 172.03만원
#
# 2021-10-12 : BUY 002290 -> 169주 구입, 매수 금액: 85.514만원
# 2021-10-12 : BUY 020180 -> 623주 구입, 매수 금액: 85.974만원
# 2021-10-13 : SELL 002290 -> 매도 금액 : 86.359만원, 전날 대비 상승률 0.009881422924901129:, 이익금 : 0.845만원, 현재 자산 : 86.90만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 90.0235만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 4.0495만원, 현재 자산 : 176.92만원
#
# 2021-10-15 : BUY 185490 -> 68주 구입, 매수 금액: 176.46만원
# 2021-10-18 : SELL 185490 -> 매도 금액 : 166.6만원, 전날 대비 상승률 -0.055876685934489356:, 이익금 : -9.86만원, 현재 자산 : 167.06만원
#
# 2021-10-18 : BUY 185490 -> 68주 구입, 매수 금액: 166.6만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 167.62만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 1.02만원, 현재 자산 : 168.08만원
#
# 2021-11-05 : BUY 025550 -> 354주 구입, 매수 금액: 167.796만원
# 2021-11-08 : SELL 025550 -> 매도 금액 : 159.477만원, 전날 대비 상승률 -0.04957805907172996:, 이익금 : -8.319만원, 현재 자산 : 159.76만원
#
# 2021-11-10 : BUY 033830 -> 1298주 구입, 매수 금액: 159.654만원
# 2021-11-11 : SELL 033830 -> 매도 금액 : 156.409만원, 전날 대비 상승률 -0.020325203252032575:, 이익금 : -3.245만원, 현재 자산 : 156.52만원
#
# 2021-11-11 : BUY 189860 -> 176주 구입, 매수 금액: 155.76만원
# 2021-11-12 : SELL 189860 -> 매도 금액 : 158.928만원, 전날 대비 상승률 0.02033898305084736:, 이익금 : 3.168만원, 현재 자산 : 159.69만원
#
# 2021-11-26 : BUY 136510 -> 58주 구입, 매수 금액: 157.76만원
# 2021-11-29 : SELL 136510 -> 매도 금액 : 133.11만원, 전날 대비 상승률 -0.15625:, 이익금 : -24.65만원, 현재 자산 : 135.03만원
#
# 2021-11-29 : BUY 136510 -> 58주 구입, 매수 금액: 133.11만원
# 2021-11-30 : SELL 136510 -> 매도 금액 : 93.38만원, 전날 대비 상승률 -0.2984749455337691:, 이익금 : -39.73만원, 현재 자산 : 95.31만원
#
# 2021-11-30 : BUY 136510 -> 59주 구입, 매수 금액: 94.99만원
# 2021-12-01 : SELL 136510 -> 매도 금액 : 86.435만원, 전날 대비 상승률 -0.09006211180124224:, 이익금 : -8.555만원, 현재 자산 : 86.75만원
#
# 2021-12-15 : BUY 121850 -> 269주 구입, 매수 금액: 86.5911만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 141.61만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 6.37만원, 현재 자산 : 278.40만원
#
# 2021-10-18 : BUY 185490 -> 113주 구입, 매수 금액: 276.85만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 278.545만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 1.695만원, 현재 자산 : 280.09만원
#
# 2021-11-05 : BUY 025550 -> 590주 구입, 매수 금액: 279.66만원
# 2021-11-08 : SELL 025550 -> 매도 금액 : 265.795만원, 전날 대비 상승률 -0.04957805907172996:, 이익금 : -13.865만원, 현재 자산 : 266.23만원
#
# 2021-11-08 : BUY 039240 -> 613주 구입, 매수 금액: 266.042만원
# 2021-11-09 : SELL 039240 -> 매도 금액 : 255.621만원, 전날 대비 상승률 -0.03917050691244239:, 이익금 : -10.421만원, 현재 자산 : 255.80만원
#
# 2021-11-10 : BUY 033830 -> 2079주 구입, 매수 금액: 255.717만원
# 2021-11-11 : SELL 033830 -> 매도 금액 : 250.5195만원, 전날 대비 상승률 -0.020325203252032575:, 이익금 : -5.1975만원, 현재 자산 : 250.61만원
#
# 2021-11-11 : BUY 189860 -> 283주 구입, 매수 금액: 250.455만원
# 2021-11-12 : SELL 189860 -> 매도 금액 : 255.549만원, 전날 대비 상승률 0.02033898305084736:, 이익금 : 5.094만원, 현재 자산 : 255.70만원
#
#  earning_rate : 255.7014
# 시작 금액 : 100.0 만원
#
# 2021-01-04 : BUY 083420 -> 91주 구입, 매수 금액: 99.645만원
# 2021-01-05 : SELL 083420 -> 매도 금액 : 96.915만원, 전날 대비 상승률 -0.0273972602739726:, 이익금 : -2.73만원, 현재 자산 : 97.27만원
#
# 2021-01-26 : BUY 004560 -> 58주 구입, 매수 금액: 95.7만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 124.41만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 28.71만원, 현재 자산 : 125.98만원
#
# 2021-02-15 : BUY 051980 -> 738주 구입, 매수 금액: 125.829만원
# 2021-02-16 : SELL 051980 -> 매도 금액 : 132.102만원, 전날 대비 상승률 0.04985337243401755:, 이익금 : 6.273만원, 현재 자산 : 132.25만원
#
# 2021-02-23 : BUY 115450 -> 72주 구입, 매수 금액: 131.04만원
# 2021-02-24 : SELL 115450 -> 매도 금액 : 156.24만원, 전날 대비 상승률 0.1923076923076923:, 이익금 : 25.2만원, 현재 자산 : 157.45만원
#
# 2021-03-02 : BUY 065680 -> 62주 구입, 매수 금액: 155.62만원
# 2021-03-03 : SELL 065680 -> 매도 금액 : 154.07만원, 전날 대비 상승률 -0.009960159362549792:, 이익금 : -1.55만원, 현재 자산 : 155.90만원
#
# 2021-03-08 : BUY 009620 -> 1277주 구입, 매수 금액: 155.794만원
# 2021-03-09 : SELL 009620 -> 매도 금액 : 161.5405만원, 전날 대비 상승률 0.03688524590163933:, 이익금 : 5.7465만원, 현재 자산 : 161.65만원
#
# 2021-10-07 : SELL 078650 -> 매도 금액 : 76.7398만원, 전날 대비 상승률 0.06153722721437749:, 이익금 : 4.4486만원, 현재 자산 : 244.70만원
#
# 2021-10-07 : BUY 002290 -> 216주 구입, 매수 금액: 122.256만원
# 2021-10-07 : BUY 020180 -> 799주 구입, 매수 금액: 122.247만원
# 2021-10-08 : SELL 002290 -> 매도 금액 : 124.2만원, 전날 대비 상승률 0.01590106007067127:, 이익금 : 1.944만원, 현재 자산 : 124.39만원
# 2021-10-08 : SELL 020180 -> 매도 금액 : 125.0435만원, 전날 대비 상승률 0.02287581699346397:, 이익금 : 2.7965만원, 현재 자산 : 249.44만원
#
# 2021-10-15 : BUY 185490 -> 96주 구입, 매수 금액: 249.12만원
# 2021-10-18 : SELL 185490 -> 매도 금액 : 235.2만원, 전날 대비 상승률 -0.055876685934489356:, 이익금 : -13.92만원, 현재 자산 : 235.52만원
#
# 2021-10-18 : BUY 185490 -> 96주 구입, 매수 금액: 235.2만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 236.64만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 1.44만원, 현재 자산 : 236.96만원
#
# 2021-10-28 : BUY 136510 -> 217주 구입, 매수 금액: 236.53만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 307.055만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 70.525만원, 현재 자산 : 307.48만원
#
# 2021-11-05 : BUY 126600 -> 258주 구입, 매수 금액: 307.02만원
# 2021-11-08 : SELL 126600 -> 매도 금액 : 264.45만원, 전날 대비 상승률 -0.1386554621848739:, 이익금 : -42.57만원, 현재 자산 : 264.91만원
#
# 2021-12-07 : BUY 001140 -> 1576주 구입, 매수 금액: 264.768만원
# 2021-12-08 : SELL 001140 -> 매도 금액 : 270.284만원, 전날 대비 상승률 0.02083333333333326:, 이익금 : 5.516만원, 현재 자산 : 270.43만원
#
# 2021-12-28 : BUY 219550 -> 1079주 구입, 매수 금액: 270.2895만원
# 2021-12-29 : SELL 219550 -> 매도 금액 : 316.147만원, 전날 대비 상승률 0.1696606786427146:, 이익금 : 45.8575만원, 현재 자산 : 316.29만원
#
#  earning_rate : 316.2865
# 시작 금액 : 100.0 만원
#
# 2021-01-07 : BUY 045340 -> 67주 구입, 매수 금액: 99.495만원
# 2021-01-08 : SELL 045340 -> 매도 금액 : 102.51만원, 전날 대비 상승률 0.030303030303030276:, 이익금 : 3.015만원, 현재 자산 : 103.02만원
#
# 2021-01-26 : BUY 004560 -> 31주 구입, 매수 금액: 51.15만원
# 2021-01-26 : BUY 019170 -> 5주 구입, 매수 금액: 46.25만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 66.495만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 15.345만원, 현재 자산 : 72.11만원
# 2021-01-27 : SELL 019170 -> 매도 금액 : 44.8만원, 전날 대비 상승률 -0.031351351351351364:, 이익금 : -1.45만원, 현재 자산 : 116.91만원
#
# 2021-01-27 : BUY 214330 -> 352주 구입, 매수 금액: 116.688만원
# 2021-01-28 : SELL 214330 -> 매도 금액 : 116.864만원, 전날 대비 상승률 0.0015082956259426794:, 이익금 : 0.176만원, 현재 자산 : 117.09만원
#
# 2021-01-29 : BUY 023960 -> 248주 구입, 매수 금액: 116.932만원
# 2021-02-01 : SELL 023960 -> 매도 금액 : 127.72만원, 전날 대비 상승률 0.09225874867444328:, 이익금 : 10.788만원, 현재 자산 : 127.87만원
#
# 2021-02-15 : BUY 208640 -> 311주 구입, 매수 금액: 63.755만원
# 2021-02-15 : BUY 004140 -> 66주 구입, 매수 금액: 63.4788만원
# 2021-02-16 : SELL 208640 -> 매도 금액 : 61.7335만원, 전날 대비 상승률 -0.03170731707317076:, 이익금 : -2.0215만원, 현재 자산 : 62.37만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 82.4538만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 18.975만원, 현재 자산 : 144.83만원
#
# 2021-02-19 : BUY 044480 -> 622주 구입, 매수 금액: 144.615만원
# 2021-02-22 : SELL 044480 -> 매도 금액 : 147.414만원, 전날 대비 상승률 0.019354838709677358:, 이익금 : 2.799만원, 현재 자산 : 147.63만원
#
# 2021-03-08 : BUY 009620 -> 1210주 구입, 매수 금액: 147.62만원
# 2021-03-09 : SELL 009620 -> 매도 금액 : 153.065만원, 전날 대비 상승률 0.03688524590163933:, 이익금 : 5.445만원, 현재 자산 : 153.07만원
#
# 2021-03-12 : BUY 006200 -> 882주 구입, 매수 금액: 153.027만원
# 2021-03-15 : SELL 006200 -> 매도 금액 : 138.474만원, 전날 대비 상승률 -0.09510086455331412:, 이익금 : -14.553만원, 현재 자산 : 138.52만원
#
# 2021-03-15 : BUY 053030 -> 85주 구입, 매수 금액: 137.275만원
# 2021-03-16 : SELL 053030 -> 매도 금액 : 168.3만원, 전날 대비 상승률 0.22600619195046434:, 이익금 : 31.025만원, 현재 자산 : 169.54만원
#
# 2021-03-16 : BUY 014530 -> 365주 구입, 매수 금액: 169.5425만원
# 2021-03-17 : SELL 014530 -> 매도 금액 : 175.565만원, 전날 대비 상승률 0.03552206673842839:, 이익금 : 6.0225만원, 현재 자산 : 175.57만원
#
# 2021-03-23 : BUY 049830 -> 52주 구입, 매수 금액: 86.32만원
# 2021-03-23 : BUY 004770 -> 264주 구입, 매수 금액: 87.78만원
# 2021-03-24 : SELL 049830 -> 매도 금액 : 86.32만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 87.79만원
# 2021-03-24 : SELL 004770 -> 매도 금액 : 84.876만원, 전날 대비 상승률 -0.03308270676691727:, 이익금 : -2.904만원, 현재 자산 : 172.66만원
#
# 2021-03-25 : BUY 064090 -> 475주 구입, 매수 금액: 172.33만원
# 2021-03-26 : SELL 064090 -> 매도 금액 : 196.27만원, 전날 대비 상승률 0.1389195148842337:, 이익금 : 23.94만원, 현재 자산 : 196.60만원
# 2021-05-31 : BUY 136510 -> 832주 구입, 매수 금액: 192.0256만원
# 2021-06-01 : SELL 136510 -> 매도 금액 : 248.6016만원, 전날 대비 상승률 0.2946273830155979:, 이익금 : 56.576만원, 현재 자산 : 248.82만원
#
# 2021-06-01 : BUY 101390 -> 101주 구입, 매수 금액: 124.1896만원
# 2021-06-01 : BUY 136510 -> 416주 구입, 매수 금액: 124.3008만원
# 2021-06-02 : SELL 101390 -> 매도 금액 : 135.8955만원, 전날 대비 상승률 0.09425829538061148:, 이익금 : 11.7059만원, 현재 자산 : 136.23만원
# 2021-06-02 : SELL 136510 -> 매도 금액 : 161.2416만원, 전날 대비 상승률 0.29718875502008024:, 이익금 : 36.9408만원, 현재 자산 : 297.47만원
#
# 2021-06-03 : BUY 101390 -> 201주 구입, 매수 금액: 296.7765만원
# 2021-06-04 : SELL 101390 -> 매도 금액 : 297.7815만원, 전날 대비 상승률 0.0033863867253640656:, 이익금 : 1.005만원, 현재 자산 : 298.48만원
#
# 2021-08-17 : BUY 019490 -> 732주 구입, 매수 금액: 298.29만원
# 2021-08-18 : SELL 019490 -> 매도 금액 : 298.29만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 298.48만원
#
# 2021-08-18 : BUY 950130 -> 82주 구입, 매수 금액: 147.6만원
# 2021-08-18 : BUY 078650 -> 79주 구입, 매수 금액: 148.6859만원
# 2021-08-19 : SELL 950130 -> 매도 금액 : 139.4만원, 전날 대비 상승률 -0.05555555555555558:, 이익금 : -8.2만원, 현재 자산 : 141.59만원
# 2021-08-19 : SELL 078650 -> 매도 금액 : 124.6462만원, 전날 대비 상승률 -0.1616811008979332:, 이익금 : -24.0397만원, 현재 자산 : 266.24만원
#
# 2021-08-19 : BUY 019490 -> 717주 구입, 매수 금액: 266.007만원
# 2021-08-20 : SELL 019490 -> 매도 금액 : 307.593만원, 전날 대비 상승률 0.15633423180592998:, 이익금 : 41.586만원, 현재 자산 : 307.82만원
#
# 2021-08-20 : BUY 065440 -> 986주 구입, 매수 금액: 307.632만원
# 2021-08-23 : SELL 065440 -> 매도 금액 : 304.674만원, 전날 대비 상승률 -0.009615384615384581:, 이익금 : -2.958만원, 현재 자산 : 304.86만원
#
# 2021-08-24 : BUY 950130 -> 173주 구입, 매수 금액: 304.48만원
# 2021-08-25 : SELL 950130 -> 매도 금액 : 305.345만원, 전날 대비 상승률 0.0028409090909091717:, 이익금 : 0.865만원, 현재 자산 : 305.73만원
#
# 2021-08-27 : BUY 093640 -> 654주 구입, 매수 금액: 305.418만원
# 2021-08-30 : SELL 093640 -> 매도 금액 : 309.015만원, 전날 대비 상승률 0.01177730192719495:, 이익금 : 3.597만원, 현재 자산 : 309.33만원
#
# 2021-09-09 : BUY 042040 -> 1808주 구입, 매수 금액: 309.168만원
# 2021-09-10 : SELL 042040 -> 매도 금액 : 310.072만원, 전날 대비 상승률 0.0029239766081872176:, 이익금 : 0.904만원, 현재 자산 : 310.23만원
#
# 2021-09-23 : BUY 057880 -> 2096주 구입, 매수 금액: 310.208만원
# 2021-09-24 : SELL 057880 -> 매도 금액 : 319.64만원, 전날 대비 상승률 0.030405405405405483:, 이익금 : 9.432만원, 현재 자산 : 319.66만원
#
# 2021-09-24 : BUY 042040 -> 2004주 구입, 매수 금액: 319.638만원
# 2021-09-27 : SELL 042040 -> 매도 금액 : 300.6만원, 전날 대비 상승률 -0.059561128526645746:, 이익금 : -19.038만원, 현재 자산 : 300.62만원
# 2021-10-06 : BUY 032280 -> 139주 구입, 매수 금액: 75.06만원
# 2021-10-06 : BUY 025550 -> 94주 구입, 매수 금액: 75.106만원
# 2021-10-06 : BUY 208710 -> 259주 구입, 매수 금액: 75.11만원
# 2021-10-06 : BUY 064550 -> 13주 구입, 매수 금액: 71.11만원
# 2021-10-07 : SELL 032280 -> 매도 금액 : 83.817만원, 전날 대비 상승률 0.1166666666666667:, 이익금 : 8.757만원, 현재 자산 : 88.06만원
# 2021-10-07 : SELL 025550 -> 매도 금액 : 94.94만원, 전날 대비 상승률 0.2640801001251565:, 이익금 : 19.834만원, 현재 자산 : 183.00만원
# 2021-10-07 : SELL 208710 -> 매도 금액 : 85.211만원, 전날 대비 상승률 0.1344827586206896:, 이익금 : 10.101만원, 현재 자산 : 268.21만원
# 2021-10-07 : SELL 064550 -> 매도 금액 : 81.77만원, 전날 대비 상승률 0.14990859232175513:, 이익금 : 10.66만원, 현재 자산 : 349.98만원
#
# 2021-10-08 : BUY 208710 -> 1143주 구입, 매수 금액: 349.758만원
# 2021-10-12 : SELL 208710 -> 매도 금액 : 352.6155만원, 전날 대비 상승률 0.008169934640522847:, 이익금 : 2.8575만원, 현재 자산 : 352.83만원
#
# 2021-10-12 : BUY 020180 -> 2556주 구입, 매수 금액: 352.728만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 369.342만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 16.614만원, 현재 자산 : 369.45만원
#
# 2021-10-15 : BUY 185490 -> 142주 구입, 매수 금액: 368.49만원
# 2021-10-18 : SELL 185490 -> 매도 금액 : 347.9만원, 전날 대비 상승률 -0.055876685934489356:, 이익금 : -20.59만원, 현재 자산 : 348.86만원
#
# 2021-10-18 : BUY 185490 -> 142주 구입, 매수 금액: 347.9만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 350.03만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 2.13만원, 현재 자산 : 350.99만원
#
# 2021-10-28 : BUY 136510 -> 322주 구입, 매수 금액: 350.98만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 455.63만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 104.65만원, 현재 자산 : 455.64만원
#
# 2021-10-29 : BUY 039240 -> 559주 구입, 매수 금액: 455.026만원
# 2021-11-01 : SELL 039240 -> 매도 금액 : 447.2만원, 전날 대비 상승률 -0.017199017199017175:, 이익금 : -7.826만원, 현재 자산 : 447.81만원
#
# 2021-11-03 : BUY 078650 -> 593주 구입, 매수 금액: 447.7743만원
# 2021-11-04 : SELL 078650 -> 매도 금액 : 421.03만원, 전날 대비 상승률 -0.05972718845186065:, 이익금 : -26.7443만원, 현재 자산 : 421.07만원
#
# 2021-11-05 : BUY 032280 -> 474주 구입, 매수 금액: 140.067만원
# 2021-11-05 : BUY 025550 -> 296주 구입, 매수 금액: 140.304만원
# 2021-11-05 : BUY 126600 -> 117주 구입, 매수 금액: 139.23만원
# 2021-11-08 : SELL 032280 -> 매도 금액 : 137.934만원, 전날 대비 상승률 -0.015228426395939132:, 이익금 : -2.133만원, 현재 자산 : 139.40만원
# 2021-11-08 : SELL 025550 -> 매도 금액 : 133.348만원, 전날 대비 상승률 -0.04957805907172996:, 이익금 : -6.956만원, 현재 자산 : 272.75만원
# 2021-11-08 : SELL 126600 -> 매도 금액 : 119.925만원, 전날 대비 상승률 -0.1386554621848739:, 이익금 : -19.305만원, 현재 자산 : 392.67만원
#
# 2021-11-08 : BUY 039240 -> 904주 구입, 매수 금액: 392.336만원
# 2021-11-09 : SELL 039240 -> 매도 금액 : 376.968만원, 전날 대비 상승률 -0.03917050691244239:, 이익금 : -15.368만원, 현재 자산 : 377.31만원
#
# 2021-11-10 : BUY 134580 -> 836주 구입, 매수 금액: 377.036만원
# 2021-11-11 : SELL 134580 -> 매도 금액 : 489.896만원, 전날 대비 상승률 0.29933481152993346:, 이익금 : 112.86만원, 현재 자산 : 490.17만원
#
# 2021-11-11 : BUY 134580 -> 836주 구입, 매수 금액: 489.896만원
# 2021-11-12 : SELL 134580 -> 매도 금액 : 636.196만원, 전날 대비 상승률 0.2986348122866893:, 이익금 : 146.3만원, 현재 자산 : 636.47만원
#
#  earning_rate : 636.4656
# 시작 금액 : 100.0 만원
#
# 2021-01-04 : BUY 080580 -> 58주 구입, 매수 금액: 99.035만원
# 2021-01-05 : SELL 080580 -> 매도 금액 : 127.6만원, 전날 대비 상승률 0.28843338213762815:, 이익금 : 28.565만원, 현재 자산 : 128.56만원
#
# 2021-01-18 : BUY 204840 -> 680주 구입, 매수 금액: 128.52만원
# 2021-01-19 : SELL 204840 -> 매도 금액 : 109.82만원, 전날 대비 상승률 -0.14550264550264547:, 이익금 : -18.7만원, 현재 자산 : 109.86만원
#
# 2021-01-26 : BUY 004560 -> 66주 구입, 매수 금액: 108.9만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 141.57만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 32.67만원, 현재 자산 : 142.53만원
#
# 2021-01-27 : BUY 214330 -> 429주 구입, 매수 금액: 142.2135만원
# 2021-01-28 : SELL 214330 -> 매도 금액 : 142.428만원, 전날 대비 상승률 0.0015082956259426794:, 이익금 : 0.2145만원, 현재 자산 : 142.75만원
#
# 2021-01-29 : BUY 071670 -> 40주 구입, 매수 금액: 71.2만원
# 2021-01-29 : BUY 023960 -> 151주 구입, 매수 금액: 71.1965만원
# 2021-02-01 : SELL 071670 -> 매도 금액 : 73.2만원, 전날 대비 상승률 0.028089887640449396:, 이익금 : 2.0만원, 현재 자산 : 73.55만원
# 2021-02-01 : SELL 023960 -> 매도 금액 : 77.765만원, 전날 대비 상승률 0.09225874867444328:, 이익금 : 6.5685만원, 현재 자산 : 151.32만원
#
# 2021-02-15 : BUY 208640 -> 369주 구입, 매수 금액: 75.645만원
# 2021-02-15 : BUY 004140 -> 78주 구입, 매수 금액: 75.0204만원
# 2021-02-16 : SELL 208640 -> 매도 금액 : 73.2465만원, 전날 대비 상승률 -0.03170731707317076:, 이익금 : -2.3985만원, 현재 자산 : 73.90만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 97.4454만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 22.425만원, 현재 자산 : 171.34만원
#
# 2021-02-18 : BUY 051980 -> 1084주 구입, 매수 금액: 171.272만원
# 2021-02-19 : SELL 051980 -> 매도 금액 : 200.54만원, 전날 대비 상승률 0.1708860759493671:, 이익금 : 29.268만원, 현재 자산 : 200.61만원
#
# 2021-03-02 : BUY 114630 -> 162주 구입, 매수 금액: 99.792만원
# 2021-03-02 : BUY 065680 -> 39주 구입, 매수 금액: 97.89만원
# 2021-03-03 : SELL 114630 -> 매도 금액 : 103.68만원, 전날 대비 상승률 0.03896103896103886:, 이익금 : 3.888만원, 현재 자산 : 106.61만원
# 2021-03-03 : SELL 065680 -> 매도 금액 : 96.915만원, 전날 대비 상승률 -0.009960159362549792:, 이익금 : -0.975만원, 현재 자산 : 203.53만원
#
# 2021-03-16 : BUY 014530 -> 438주 구입, 매수 금액: 203.451만원
# 2021-03-17 : SELL 014530 -> 매도 금액 : 210.678만원, 전날 대비 상승률 0.03552206673842839:, 이익금 : 7.227만원, 현재 자산 : 210.75만원
#
# 2021-03-23 : BUY 089530 -> 713주 구입, 매수 금액: 210.6202만원
# 2021-03-24 : SELL 089530 -> 매도 금액 : 215.2547만원, 전날 대비 상승률 0.022004062288422555:, 이익금 : 4.6345만원, 현재 자산 : 215.39만원
#
# 2021-03-24 : BUY 065500 -> 579주 구입, 매수 금액: 215.3301만원
# 2021-03-25 : SELL 065500 -> 매도 금액 : 205.6608만원, 전날 대비 상승률 -0.04490454423232049:, 이익금 : -9.6693만원, 현재 자산 : 205.72만원
#
# 2021-03-29 : BUY 064090 -> 530주 구입, 매수 금액: 205.64만원
# 2021-03-30 : SELL 064090 -> 매도 금액 : 224.349만원, 전날 대비 상승률 0.09097938144329887:, 이익금 : 18.709만원, 현재 자산 : 224.43만원
#
# 2021-03-30 : BUY 065500 -> 247주 구입, 매수 금액: 111.7675만원
# 2021-03-30 : BUY 064090 -> 265주 구입, 매수 금액: 112.1745만원
# 2021-03-31 : SELL 065500 -> 매도 금액 : 129.6503만원, 전날 대비 상승률 0.15999999999999992:, 이익금 : 17.8828만원, 현재 자산 : 130.13만원
# 2021-03-31 : SELL 064090 -> 매도 금액 : 105.152만원, 전날 대비 상승률 -0.06260335459485:, 이익금 : -7.0225만원, 현재 자산 : 235.29만원
#
# 2021-04-01 : BUY 224060 -> 9190주 구입, 매수 금액: 235.264만원
# 2021-04-02 : SELL 224060 -> 매도 금액 : 239.859만원, 전날 대비 상승률 0.01953125:, 이익금 : 4.595만원, 현재 자산 : 239.88만원
#
# 2021-04-16 : BUY 021080 -> 421주 구입, 매수 금액: 239.549만원
# 2021-04-19 : SELL 021080 -> 매도 금액 : 218.078만원, 전날 대비 상승률 -0.08963093145869949:, 이익금 : -21.471만원, 현재 자산 : 218.41만원
#
# 2021-04-23 : BUY 041190 -> 109주 구입, 매수 금액: 108.346만원
# 2021-04-23 : BUY 003530 -> 212주 구입, 매수 금액: 108.756만원
# 2021-04-26 : SELL 041190 -> 매도 금액 : 111.18만원, 전날 대비 상승률 0.026156941649899457:, 이익금 : 2.834만원, 현재 자산 : 112.49만원
# 2021-04-26 : SELL 003530 -> 매도 금액 : 110.876만원, 전날 대비 상승률 0.01949317738791434:, 이익금 : 2.12만원, 현재 자산 : 223.37만원
#
# 2021-04-26 : BUY 208640 -> 652주 구입, 매수 금액: 223.31만원
# 2021-04-27 : SELL 208640 -> 매도 금액 : 216.138만원, 전날 대비 상승률 -0.03211678832116793:, 이익금 : -7.172만원, 현재 자산 : 216.19만원
#
# 2021-05-03 : BUY 019170 -> 35주 구입, 매수 금액: 214.55만원
# 2021-05-04 : SELL 019170 -> 매도 금액 : 210.7만원, 전날 대비 상승률 -0.01794453507340943:, 이익금 : -3.85만원, 현재 자산 : 212.34만원
#
# 2021-05-06 : BUY 002690 -> 472주 구입, 매수 금액: 212.3056만원
# 2021-05-07 : SELL 002690 -> 매도 금액 : 236.0944만원, 전날 대비 상승률 0.11204979991107167:, 이익금 : 23.7888만원, 현재 자산 : 236.13만원
#
# 2021-05-21 : BUY 024940 -> 204주 구입, 매수 금액: 235.62만원
# 2021-05-24 : SELL 024940 -> 매도 금액 : 263.16만원, 전날 대비 상승률 0.11688311688311681:, 이익금 : 27.54만원, 현재 자산 : 263.67만원
#
# 2021-05-25 : BUY 032860 -> 387주 구입, 매수 금액: 263.547만원
# 2021-05-26 : SELL 032860 -> 매도 금액 : 342.495만원, 전날 대비 상승률 0.2995594713656389:, 이익금 : 78.948만원, 현재 자산 : 342.62만원
#
# 2021-05-26 : BUY 032860 -> 387주 구입, 매수 금액: 342.495만원
# 2021-05-27 : SELL 032860 -> 매도 금액 : 359.91만원, 전날 대비 상승률 0.05084745762711873:, 이익금 : 17.415만원, 현재 자산 : 360.03만원
#
# 2021-05-31 : BUY 009620 -> 600주 구입, 매수 금액: 180.0만원
# 2021-05-31 : BUY 136510 -> 779주 구입, 매수 금액: 179.7932만원
# 2021-06-01 : SELL 009620 -> 매도 금액 : 195.0만원, 전날 대비 상승률 0.08333333333333326:, 이익금 : 15.0만원, 현재 자산 : 195.24만원
# 2021-06-01 : SELL 136510 -> 매도 금액 : 232.7652만원, 전날 대비 상승률 0.2946273830155979:, 이익금 : 52.972만원, 현재 자산 : 428.01만원
#
# 2021-06-29 : BUY 121850 -> 1409주 구입, 매수 금액: 427.9133만원
# 2021-06-30 : SELL 121850 -> 매도 금액 : 438.0581만원, 전날 대비 상승률 0.02370760619031942:, 이익금 : 10.1448만원, 현재 자산 : 438.15만원
#
# 2021-07-02 : BUY 121850 -> 1527주 구입, 매수 금액: 438.0963만원
# 2021-07-05 : SELL 121850 -> 매도 금액 : 440.3868만원, 전날 대비 상승률 0.005228302544440622:, 이익금 : 2.2905만원, 현재 자산 : 440.44만원
#
# 2021-07-06 : BUY 189860 -> 495주 구입, 매수 금액: 440.055만원
# 2021-07-07 : SELL 189860 -> 매도 금액 : 482.13만원, 전날 대비 상승률 0.0956130483689539:, 이익금 : 42.075만원, 현재 자산 : 482.52만원
#
# 2021-08-24 : BUY 028080 -> 682주 구입, 매수 금액: 482.174만원
# 2021-08-25 : SELL 028080 -> 매도 금액 : 465.124만원, 전날 대비 상승률 -0.03536067892503536:, 이익금 : -17.05만원, 현재 자산 : 465.47만원
#
# 2021-08-27 : BUY 093640 -> 996주 구입, 매수 금액: 465.132만원
# 2021-08-30 : SELL 093640 -> 매도 금액 : 470.61만원, 전날 대비 상승률 0.01177730192719495:, 이익금 : 5.478만원, 현재 자산 : 470.95만원
#
# 2021-08-30 : BUY 182400 -> 289주 구입, 매수 금액: 469.625만원
# 2021-08-31 : SELL 182400 -> 매도 금액 : 560.66만원, 전날 대비 상승률 0.19384615384615378:, 이익금 : 91.035만원, 현재 자산 : 561.98만원
# 2021-10-05 : BUY 013360 -> 1007주 구입, 매수 금액: 561.906만원
# 2021-10-06 : SELL 013360 -> 매도 금액 : 603.193만원, 전날 대비 상승률 0.07347670250896066:, 이익금 : 41.287만원, 현재 자산 : 603.27만원
#
# 2021-10-12 : BUY 002290 -> 1192주 구입, 매수 금액: 603.152만원
# 2021-10-13 : SELL 002290 -> 매도 금액 : 609.112만원, 전날 대비 상승률 0.009881422924901129:, 이익금 : 5.96만원, 현재 자산 : 609.23만원
#
# 2021-10-18 : BUY 025890 -> 1121주 구입, 매수 금액: 608.703만원
# 2021-10-19 : SELL 025890 -> 매도 금액 : 608.703만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 609.23만원
#
# 2021-10-21 : BUY 185490 -> 267주 구입, 매수 금액: 608.76만원
# 2021-10-22 : SELL 185490 -> 매도 금액 : 626.115만원, 전날 대비 상승률 0.028508771929824483:, 이익금 : 17.355만원, 현재 자산 : 626.58만원
#
# 2021-10-28 : BUY 136510 -> 574주 구입, 매수 금액: 625.66만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 812.21만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 186.55만원, 현재 자산 : 813.13만원
#
# 2021-10-29 : BUY 136510 -> 574주 구입, 매수 금액: 812.21만원
# 2021-11-01 : SELL 136510 -> 매도 금액 : 955.71만원, 전날 대비 상승률 0.1766784452296819:, 이익금 : 143.5만원, 현재 자산 : 956.63만원
#
# 2021-11-04 : BUY 136510 -> 331주 구입, 매수 금액: 956.59만원
# 2021-11-05 : SELL 136510 -> 매도 금액 : 956.59만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 956.63만원
#
# 2021-11-05 : BUY 126600 -> 803주 구입, 매수 금액: 955.57만원
# 2021-11-08 : SELL 126600 -> 매도 금액 : 823.075만원, 전날 대비 상승률 -0.1386554621848739:, 이익금 : -132.495만원, 현재 자산 : 824.14만원
#
# 2021-11-08 : BUY 038010 -> 1155주 구입, 매수 금액: 823.515만원
# 2021-11-09 : SELL 038010 -> 매도 금액 : 1069.53만원, 전날 대비 상승률 0.29873772791023834:, 이익금 : 246.015만원, 현재 자산 : 1070.15만원
#
# 2021-11-10 : BUY 136510 -> 219주 구입, 매수 금액: 1068.72만원
# 2021-11-11 : SELL 136510 -> 매도 금액 : 1388.46만원, 전날 대비 상승률 0.2991803278688525:, 이익금 : 319.74만원, 현재 자산 : 1389.89만원
#
# 2021-11-11 : BUY 032280 -> 2763주 구입, 매수 금액: 694.8945만원
# 2021-11-11 : BUY 115610 -> 1593주 구입, 매수 금액: 694.548만원
# 2021-11-12 : SELL 032280 -> 매도 금액 : 737.721만원, 전날 대비 상승률 0.06163021868787277:, 이익금 : 42.8265만원, 현재 자산 : 738.17만원
# 2021-11-12 : SELL 115610 -> 매도 금액 : 683.397만원, 전날 대비 상승률 -0.016055045871559592:, 이익금 : -11.151만원, 현재 자산 : 1421.57만원
#
# 2021-11-12 : BUY 032280 -> 5324주 구입, 매수 금액: 1421.508만원
# 2021-11-15 : SELL 032280 -> 매도 금액 : 1432.156만원, 전날 대비 상승률 0.0074906367041198685:, 이익금 : 10.648만원, 현재 자산 : 1432.22만원
#
# 2021-11-19 : BUY 214270 -> 1488주 구입, 매수 금액: 1431.456만원
# 2021-11-22 : SELL 214270 -> 매도 금액 : 1386.816만원, 전날 대비 상승률 -0.03118503118503113:, 이익금 : -44.64만원, 현재 자산 : 1387.58만원
#
# 2021-11-30 : BUY 017000 -> 483주 구입, 매수 금액: 693.105만원
# 2021-11-30 : BUY 029480 -> 5196주 구입, 매수 금액: 693.666만원
# 2021-12-01 : SELL 017000 -> 매도 금액 : 678.615만원, 전날 대비 상승률 -0.020905923344947785:, 이익금 : -14.49만원, 현재 자산 : 679.42만원
# 2021-12-01 : SELL 029480 -> 매도 금액 : 698.862만원, 전날 대비 상승률 0.0074906367041198685:, 이익금 : 5.196만원, 현재 자산 : 1378.28만원
#
# 2021-12-14 : BUY 121850 -> 5564주 구입, 매수 금액: 1378.2028만원
# 2021-12-15 : SELL 121850 -> 매도 금액 : 1791.0516만원, 전날 대비 상승률 0.2995559144125959:, 이익금 : 412.8488만원, 현재 자산 : 1791.13만원
#
# 2021-12-27 : BUY 010600 -> 8978주 구입, 매수 금액: 1791.111만원
# 2021-12-28 : SELL 010600 -> 매도 금액 : 1589.106만원, 전날 대비 상승률 -0.1127819548872181:, 이익금 : -202.005만원, 현재 자산 : 1589.13만원
#
#  earning_rate : 1589.1254

# %%
from functools import reduce

scaling0_simul_df = pd.DataFrame(scaling0_simul, columns=['sell_date', 'money'])
scaling1_simul_df = pd.DataFrame(scaling1_simul, columns=['sell_date', 'money'])
scaling2_simul_df = pd.DataFrame(scaling2_simul, columns=['sell_date', 'money'])
scaling3_simul_df = pd.DataFrame(scaling3_simul, columns=['sell_date', 'money'])
scaling4_simul_df = pd.DataFrame(scaling4_simul, columns=['sell_date', 'money'])

dfs = [scaling0_simul_df, scaling1_simul_df, scaling2_simul_df, scaling3_simul_df, scaling4_simul_df]

# 4개의 df를 한번에 merge하기
df_merge = reduce(lambda left, right: pd.merge(left, right, on='sell_date', how='outer',sort=True), dfs)


df_merge.columns=['sell_date', 'Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']
df_merge

first_data = {
    'sell_date' : '2021-01-04', 
    'Raw Data' : 1000000,
    'MINMAX-240' : 1000000, 
    'MINMAX-10' : 1000000, 
    'DIV-LAST-CLOSE' : 1000000, 
    'DIV-EACH-CLOSE' : 1000000
}

df_merge = df_merge.append(first_data, ignore_index=True)

df_merge = df_merge.sort_values(by=['sell_date'], axis=0).reset_index()
del df_merge['index']
df_merge = df_merge.fillna(method='ffill')

# %%
df_merge
# Out:
#      sell_date   Raw Data  MINMAX-240  MINMAX-10  DIV-LAST-CLOSE  \
# 0   2021-01-04  1000000.0   1000000.0  1000000.0       1000000.0
# 1   2021-01-05  1000000.0   1000000.0   972700.0       1000000.0
# 2   2021-01-08  1000000.0   1000000.0   972700.0       1030150.0
# 3   2021-01-19  1000000.0   1000000.0   972700.0       1030150.0
# 4   2021-01-27  1000000.0   1000000.0  1259800.0       1169100.0
# ..         ...        ...         ...        ...             ...
# 87  2021-12-08   867500.0   2557014.0  2704290.0       6364656.0
# 88  2021-12-15   867500.0   2557014.0  2704290.0       6364656.0
# 89  2021-12-16  1126547.0   2557014.0  2704290.0       6364656.0
# 90  2021-12-28  1126547.0   2557014.0  2704290.0       6364656.0
# 91  2021-12-29  1126547.0   2557014.0  3162865.0       6364656.0
#
#     DIV-EACH-CLOSE
# 0        1000000.0
# 1        1285650.0
# 2        1285650.0
# 3        1098650.0
# 4        1425350.0
# ..             ...
# 87      13782816.0
# 88      17911304.0
# 89      17911304.0
# 90      15891254.0
# 91      15891254.0
#
# [92 rows x 6 columns]

# %%
 df_merge[['Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']] = df_merge[['Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']]/10000 - 100

# %%
import matplotlib as mpl
label_lst = ['Raw Data','MINMAX-240','MINMAX-10','DIV-LAST-CLOSE','DIV-EACH-CLOSE']

mpl.rcParams['axes.unicode_minus'] = False
f,ax = plt.subplots(1,1,figsize=(25,12),sharex=False)
for i in range(5):
    ax = sns.lineplot(data = df_merge, x="sell_date", y = label_lst[i], label=label_lst[i], linewidth=4)

_=plt.xticks(range(0,91, 10), fontsize=30, rotation = 30)
_=plt.yticks(range(100,1500,300), fontsize=30)
ax.set_xlabel('거래일', fontsize=35)
ax.set_ylabel('수익률', fontsize=35)
_=plt.legend(fontsize=30)

# %% [markdown]
# \frac{abc}{def}
